# %% [markdown]
# <a href="https://colab.research.google.com/github/dmitry-kabanov/datascience/blob/main/2022-07-14-wandb-sweep-pytorch-cnn-fashion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Based on https://github.com/wandb/examples/tree/master/examples/pytorch/pytorch-cnn-fashion

# %%
# !pip install -q wandb
# Out:
#      |████████████████████████████████| 1.8 MB 7.6 MB/s
#      |████████████████████████████████| 181 kB 56.6 MB/s
#      |████████████████████████████████| 146 kB 56.0 MB/s
#      |████████████████████████████████| 63 kB 1.5 MB/s
# ...

# %%
# !git clone https://github.com/wandb/examples.git
# Out:
# Cloning into 'examples'...
# remote: Enumerating objects: 5428, done.
# remote: Counting objects: 100% (462/462), done.
# remote: Compressing objects: 100% (289/289), done.
# remote: Total 5428 (delta 214), reused 346 (delta 163), pack-reused 4966
# Receiving objects: 100% (5428/5428), 157.35 MiB | 26.02 MiB/s, done.
# Resolving deltas: 100% (2821/2821), done.

# %%
# %cd examples/examples/pytorch/pytorch-cnn-fashion
# Out:
# /content/examples/examples/pytorch/pytorch-cnn-fashion

# %%
# %ls
# Out:
# fashion_data.py  README.md  sweep-grid-hyperband.yaml  train.py*

# %%
# !python train.py
# Out:
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: dfd9a24201d49d7896a29eec79f1e7357b5456a0
# wandb: WARNING Invalid choice
# wandb: Enter your choice: 2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.12.21
# wandb: Run data is saved locally in /content/examples/examples/pytorch/pytorch-cnn-fashion/wandb/run-20220714_110246-2ueu69tp
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run dashing-frog-1
# wandb: ⭐️ View project at https://wandb.ai/dmitry-kabanov/pytorch-cnn-fashion
# ...

# %%
# !wandb agent dmitry-kabanov/pytorch-cnn-fashion/2z5p8plv
# Out:
# wandb: Starting wandb agent 🕵️
# 2022-07-14 11:12:18,615 - wandb.wandb_agent - INFO - Running runs: []
# 2022-07-14 11:13:29,109 - wandb.wandb_agent - INFO - Agent received command: run
# 2022-07-14 11:13:29,110 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	batch_size: 245
# 	channels_one: 9
# 	channels_two: 46
# 	dropout: 0.10538645267611968
# 	epochs: 1
# 	learning_rate: 0.0011486711281903173
# 2022-07-14 11:13:29,112 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --batch_size=245 --channels_one=9 --channels_two=46 --dropout=0.10538645267611968 --epochs=1 --learning_rate=0.0011486711281903173
# wandb: Currently logged in as: dmitry-kabanov. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: Tracking run with wandb version 0.12.21
# wandb: Run data is saved locally in /content/examples/examples/pytorch/pytorch-cnn-fashion/wandb/run-20220714_111331-9ayxldhz
# ...
